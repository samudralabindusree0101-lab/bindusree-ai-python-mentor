# %%
# !pip install -q streamlit pyngrok google-generativeai ipykernel
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile project.py
import streamlit as st
import google.generativeai as genai

genai.configure(api_key="your_api_key_here")  # Replace with your actual API key

model = genai.GenerativeModel("gemini-2.5-flash")

# 🎨 App UI
st.set_page_config(page_title="Bindusree AI – Python Learning Buddy", page_icon="🤖")

st.title("🤖 Bindusree AI – Python Learning Buddy")

# User Inputs
level = st.selectbox(
    "Select Your Python Level",
    ["Beginner", "Intermediate", "Advanced"]
)

topic = st.text_input("Enter Python Topic (e.g., Loops, Functions)")

# Generate Lesson
if st.button("Start Learning"):
    if topic == "":
        st.warning("Please enter a topic!")
    else:
        prompt = f"""
You are Bindusree AI – a friendly Python mentor.

Student Level: {level}
Topic: {topic}

Teach using this structure:

1. Introduction
2. Simple Explanation
3. Why It Is Important
4. Syntax
5. Real-Life Example
6. Python Code Example
7. Expected Output
8. Common Beginner Mistakes
9. Practice Question
10. Multiple Choice Quiz (5 questions, no answers)

Keep it beginner-friendly and structured.
"""

        response = model.generate_content(prompt)
        st.markdown(response.text)

# Quiz Evaluation Section
st.subheader("📝 Submit Quiz Answers")

answers = st.text_input("Enter your answers (e.g., 1-A,2-B,3-C...)")

if st.button("Evaluate Answers"):
    if answers == "" or topic == "":
        st.warning("Please enter both topic and answers!")
    else:
        eval_prompt = f"""
You are Bindusree AI.

Topic: {topic}
Student Answers: {answers}

Evaluate the answers:
- Give score out of 5
- Show correct answers
- Explain each answer
- Encourage the student
- Suggest what to revise
- Give lesson summary
- Suggest next topic
- Add motivation

Do NOT skip explanations.
"""

        result = model.generate_content(eval_prompt)
        st.markdown(result.text)
# Out:
# Overwriting project.py

# %%
# !nohup streamlit run project.py --server.port 3000
# Out:
# 'nohup' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import time
time.sleep(10)

# %%
ngrok.kill()

# %%
# !pkill ngrok

# %%
from pyngrok import ngrok
ngrok.kill()
ngrok.set_auth_token("your_ngrok_auth_token_here")  # Replace with your actual ngrok auth token

public_url = ngrok.connect(3000)
print("Your App URL:", public_url)
# Out:
# t=2026-07-11T23:38:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:38+0530 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.ngrok-agent.com/check\": dial tcp: lookup update.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:38+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:39+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:41+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:45+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:38:53+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 ngrok.kill()
#       3 ngrok.set_auth_token("3GEHz3t2j6L1v4DlYz2OPCin8eL_4i1kSCveUNki1zSJ3NSwr")
# ----> 5 public_url = ngrok.connect(3000)
#       6 print("Your App URL:", public_url)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\ngrok.py:389, in connect(addr, proto, name, pyngrok_config, **options)
#     385 api_path = "/api/endpoints" if pyngrok_config.config_version == "3" else "/api/tunnels"
#     387 logger.info(f"Opening tunnel named: {name}")
# --> 389 api_url = get_ngrok_process(pyngrok_config).api_url
#     391 logger.debug(f"Creating tunnel with options: {options}")
#     393 tunnel = NgrokTunnel(api_request(f"{api_url}{api_path}", method="POST", data=options,
#     394                                  timeout=pyngrok_config.request_timeout),
#     395                      pyngrok_config, api_url)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\ngrok.py:217, in get_ngrok_process(pyngrok_config)
#     213     pyngrok_config = conf.get_default()
#     215 install_ngrok(pyngrok_config)
# --> 217 return process.get_process(pyngrok_config)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\process.py:273, in get_process(pyngrok_config)
#     270 if is_process_running(pyngrok_config.ngrok_path):
#     271     return _current_processes[pyngrok_config.ngrok_path]
# --> 273 return _start_process(pyngrok_config)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\process.py:449, in _start_process(pyngrok_config)
#     446 kill_process(pyngrok_config.ngrok_path)
#     448 if ngrok_process.startup_error is not None:
# --> 449     raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     450                             ngrok_process.logs,
#     451                             ngrok_process.startup_error)
#     452 else:
#     453     raise PyngrokNgrokError("The ngrok process was unable to start.", ngrok_process.logs)
#
# PyngrokNgrokError: The ngrok process errored on start: failed to dial ngrok server with address "connect.us.ngrok-agent.com:443": dial tcp: lookup connect.us.ngrok-agent.com: no such host.

# %%
import subprocess
import time
from pyngrok import ngrok

# Kill old sessions
ngrok.kill()

# Set auth token
ngrok.set_auth_token("3GEHz3t2j6L1v4DlYz2OPCin8eL_4i1kSCveUNki1zSJ3NSwr")

# STEP 1: Start Streamlit
subprocess.Popen(["streamlit", "run", "project.py", "--server.port", "3000"])

# STEP 2: Wait (VERY IMPORTANT)
time.sleep(8)

# STEP 3: Start ngrok
public_url = ngrok.connect(3000)

print("Your App URL:", public_url)
# Out:
# t=2026-07-11T23:39:28+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:28+0530 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.ngrok-agent.com/check\": dial tcp: lookup update.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:28+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:29+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:31+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:35+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# t=2026-07-11T23:39:43+0530 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.us.ngrok-agent.com:443\": dial tcp: lookup connect.us.ngrok-agent.com: no such host"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# Cell In[5], line 18
#      15 time.sleep(8)
#      17 # STEP 3: Start ngrok
# ---> 18 public_url = ngrok.connect(3000)
#      20 print("Your App URL:", public_url)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\ngrok.py:389, in connect(addr, proto, name, pyngrok_config, **options)
#     385 api_path = "/api/endpoints" if pyngrok_config.config_version == "3" else "/api/tunnels"
#     387 logger.info(f"Opening tunnel named: {name}")
# --> 389 api_url = get_ngrok_process(pyngrok_config).api_url
#     391 logger.debug(f"Creating tunnel with options: {options}")
#     393 tunnel = NgrokTunnel(api_request(f"{api_url}{api_path}", method="POST", data=options,
#     394                                  timeout=pyngrok_config.request_timeout),
#     395                      pyngrok_config, api_url)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\ngrok.py:217, in get_ngrok_process(pyngrok_config)
#     213     pyngrok_config = conf.get_default()
#     215 install_ngrok(pyngrok_config)
# --> 217 return process.get_process(pyngrok_config)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\process.py:273, in get_process(pyngrok_config)
#     270 if is_process_running(pyngrok_config.ngrok_path):
#     271     return _current_processes[pyngrok_config.ngrok_path]
# --> 273 return _start_process(pyngrok_config)
#
# File c:\Users\samud\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyngrok\process.py:449, in _start_process(pyngrok_config)
#     446 kill_process(pyngrok_config.ngrok_path)
#     448 if ngrok_process.startup_error is not None:
# --> 449     raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     450                             ngrok_process.logs,
#     451                             ngrok_process.startup_error)
#     452 else:
#     453     raise PyngrokNgrokError("The ngrok process was unable to start.", ngrok_process.logs)
#
# PyngrokNgrokError: The ngrok process errored on start: failed to dial ngrok server with address "connect.us.ngrok-agent.com:443": dial tcp: lookup connect.us.ngrok-agent.com: no such host.
